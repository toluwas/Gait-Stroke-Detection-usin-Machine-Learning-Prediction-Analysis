# %%
import pandas as pd 
import numpy as np
gait_dataset = pd.read_csv('gait_features_all_subjects_with_stroke.csv')
gait_dataset
# Out:
#        step_time_left  step_time_right  force_asymmetry  stance_time_left  \
# 0              0.5936           1.6380        40.346007             1.149
# 1              1.1760           0.3810        19.952393             1.095
# 2              0.2210           1.2130         7.319214             1.119
# 3              0.3696           0.2938        10.679626             1.125
# 4              1.1360           0.2070         7.300476             1.137
# ...               ...              ...              ...               ...
# 12425          0.6050           0.6010        12.254273             0.574
# 12426          0.3090           0.3020         9.983459             0.586
# 12427          0.5890           0.6010        25.619141             0.573
# 12428          0.4508           0.4069         0.825897             0.585
# 12429          0.5920           0.6120        24.889099             0.668
#
#        swing_time_left  impulse_left  stride_length_left  vertical_disp_left  \
# 0                0.512    667.092531            0.184841            0.007396
# 1                0.495    646.403273            0.294134            0.208099
# 2                0.530    665.519074            0.141113            0.000996
# 3                0.462    662.758870            0.114275            0.002084
# 4                0.529    687.981411            0.241174            0.193034
# ...                ...           ...                 ...                 ...
# 12425            0.337    251.744427            0.541564            0.233917
# 12426            0.327    255.381918            0.537693            0.039370
# 12427            0.328    250.399083            0.558706            0.238925
# 12428            0.332    257.716022            0.398595            0.018691
# 12429            0.160    263.494839            0.560901            0.238982
#
#        foot_velocity_left  peak_force_left  ...  stance_time_right  \
# 0                0.435459       825.101379  ...             -0.553
# 1                0.250811       817.153992  ...             -0.548
# 2                0.627357       817.774231  ...             -0.551
# 3                0.439638       803.586792  ...             -0.526
# 4                0.211679       782.675293  ...             -0.576
# ...                   ...              ...  ...                ...
# 12425            0.896681       667.596069  ...             -0.338
# 12426            1.739953       648.780884  ...             -0.333
# 12427            0.959532       633.162048  ...             -0.340
# 12428            1.228639       647.111694  ...             -0.330
# 12429            0.952942       684.690918  ...             -0.342
#
#        swing_time_right  impulse_right  vertical_disp_right  \
# 0                 2.162            0.0             0.122993
# 1                 2.157            0.0             0.007193
# 2                 2.194            0.0             0.195043
# 3                 2.121            0.0             0.001601
# 4                 2.205            0.0             0.007193
# ...                 ...            ...                  ...
# 12425             1.242            0.0             0.231840
# 12426             1.256            0.0             0.029723
# 12427             1.241            0.0             0.231399
# 12428             1.245            0.0             0.020171
# 12429             1.253            0.0             0.229939
#
#        foot_velocity_right  stride_length_right  step_width  subject  speed  \
# 0                 0.141867             0.191281    0.099112        1    0.6
# 1                 0.620570             0.235685    0.076835        1    0.6
# 2                 0.182083             0.220041    0.107222        1    0.6
# 3                 0.436198             0.105134    0.104683        1    0.6
# 4                 0.610970             0.125020    0.110397        1    0.6
# ...                    ...                  ...         ...      ...    ...
# 12425             0.912840             0.546482    0.106736       21    1.7
# 12426             1.745002             0.522435    0.107241       21    1.7
# 12427             0.864920             0.521877    0.129488       21    1.7
# 12428             1.215733             0.402852    0.117958       21    1.7
# 12429             0.828826             0.508210    0.084833       21    1.7
#
#        target
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ...       ...
# 12425       0
# 12426       0
# 12427       0
# 12428       1
# 12429       0
#
# [12430 rows x 22 columns]

# %%
gait_dataset.columns
# Out:
# Index(['step_time_left', 'step_time_right', 'force_asymmetry',
#        'stance_time_left', 'swing_time_left', 'impulse_left',
#        'stride_length_left', 'vertical_disp_left', 'foot_velocity_left',
#        'peak_force_left', 'peak_force_right', 'step_time_diff',
#        'stance_time_right', 'swing_time_right', 'impulse_right',
#        'vertical_disp_right', 'foot_velocity_right', 'stride_length_right',
#        'step_width', 'subject', 'speed', 'target'],
#       dtype='object')

# %%
len(gait_dataset)
# Out:
# 12430

# %%
gait_dataset = gait_dataset.drop(['subject', 'speed'], axis=1)
gait_dataset.head()
# Out:
#    step_time_left  step_time_right  force_asymmetry  stance_time_left  \
# 0          0.5936           1.6380        40.346007             1.149
# 1          1.1760           0.3810        19.952393             1.095
# 2          0.2210           1.2130         7.319214             1.119
# 3          0.3696           0.2938        10.679626             1.125
# 4          1.1360           0.2070         7.300476             1.137
#
#    swing_time_left  impulse_left  stride_length_left  vertical_disp_left  \
# 0            0.512    667.092531            0.184841            0.007396
# 1            0.495    646.403273            0.294134            0.208099
# 2            0.530    665.519074            0.141113            0.000996
# 3            0.462    662.758870            0.114275            0.002084
# 4            0.529    687.981411            0.241174            0.193034
#
#    foot_velocity_left  peak_force_left  peak_force_right  step_time_diff  \
# 0            0.435459       825.101379        798.204041           1.672
# 1            0.250811       817.153992        797.201599           0.795
# 2            0.627357       817.774231        810.455017           0.992
# 3            0.439638       803.586792        796.467041           0.076
# 4            0.211679       782.675293        775.374817           0.929
#
#    stance_time_right  swing_time_right  impulse_right  vertical_disp_right  \
# 0             -0.553             2.162            0.0             0.122993
# 1             -0.548             2.157            0.0             0.007193
# 2             -0.551             2.194            0.0             0.195043
# 3             -0.526             2.121            0.0             0.001601
# 4             -0.576             2.205            0.0             0.007193
#
#    foot_velocity_right  stride_length_right  step_width  target
# 0             0.141867             0.191281    0.099112       1
# 1             0.620570             0.235685    0.076835       0
# 2             0.182083             0.220041    0.107222       0
# 3             0.436198             0.105134    0.104683       1
# 4             0.610970             0.125020    0.110397       0

# %%
# Replace 'stroke_status' with your actual target column name
X = gait_dataset.drop('target', axis=1)  # Independent variables
y = gait_dataset['target']               # Dependent variable

# %%
X
# Out:
#        step_time_left  step_time_right  force_asymmetry  stance_time_left  \
# 0              0.5936           1.6380        40.346007             1.149
# 1              1.1760           0.3810        19.952393             1.095
# 2              0.2210           1.2130         7.319214             1.119
# 3              0.3696           0.2938        10.679626             1.125
# 4              1.1360           0.2070         7.300476             1.137
# ...               ...              ...              ...               ...
# 12425          0.6050           0.6010        12.254273             0.574
# 12426          0.3090           0.3020         9.983459             0.586
# 12427          0.5890           0.6010        25.619141             0.573
# 12428          0.4508           0.4069         0.825897             0.585
# 12429          0.5920           0.6120        24.889099             0.668
#
#        swing_time_left  impulse_left  stride_length_left  vertical_disp_left  \
# 0                0.512    667.092531            0.184841            0.007396
# 1                0.495    646.403273            0.294134            0.208099
# 2                0.530    665.519074            0.141113            0.000996
# 3                0.462    662.758870            0.114275            0.002084
# 4                0.529    687.981411            0.241174            0.193034
# ...                ...           ...                 ...                 ...
# 12425            0.337    251.744427            0.541564            0.233917
# 12426            0.327    255.381918            0.537693            0.039370
# 12427            0.328    250.399083            0.558706            0.238925
# 12428            0.332    257.716022            0.398595            0.018691
# 12429            0.160    263.494839            0.560901            0.238982
#
#        foot_velocity_left  peak_force_left  peak_force_right  step_time_diff  \
# 0                0.435459       825.101379        798.204041           1.672
# 1                0.250811       817.153992        797.201599           0.795
# 2                0.627357       817.774231        810.455017           0.992
# 3                0.439638       803.586792        796.467041           0.076
# 4                0.211679       782.675293        775.374817           0.929
# ...                   ...              ...               ...             ...
# 12425            0.896681       667.596069        679.850342           0.004
# 12426            1.739953       648.780884        658.764343           0.007
# 12427            0.959532       633.162048        658.781189           0.012
# 12428            1.228639       647.111694        647.662292           0.018
# 12429            0.952942       684.690918        659.801819           0.020
#
#        stance_time_right  swing_time_right  impulse_right  \
# 0                 -0.553             2.162            0.0
# 1                 -0.548             2.157            0.0
# 2                 -0.551             2.194            0.0
# 3                 -0.526             2.121            0.0
# 4                 -0.576             2.205            0.0
# ...                  ...               ...            ...
# 12425             -0.338             1.242            0.0
# 12426             -0.333             1.256            0.0
# 12427             -0.340             1.241            0.0
# 12428             -0.330             1.245            0.0
# 12429             -0.342             1.253            0.0
#
#        vertical_disp_right  foot_velocity_right  stride_length_right  \
# 0                 0.122993             0.141867             0.191281
# 1                 0.007193             0.620570             0.235685
# 2                 0.195043             0.182083             0.220041
# 3                 0.001601             0.436198             0.105134
# 4                 0.007193             0.610970             0.125020
# ...                    ...                  ...                  ...
# 12425             0.231840             0.912840             0.546482
# 12426             0.029723             1.745002             0.522435
# 12427             0.231399             0.864920             0.521877
# 12428             0.020171             1.215733             0.402852
# 12429             0.229939             0.828826             0.508210
#
#        step_width
# 0        0.099112
# 1        0.076835
# 2        0.107222
# 3        0.104683
# 4        0.110397
# ...           ...
# 12425    0.106736
# 12426    0.107241
# 12427    0.129488
# 12428    0.117958
# 12429    0.084833
#
# [12430 rows x 19 columns]

# %%
gait_dataset['target'].value_counts()
# Out:
# target
# 0    7458
# 1    4972
# Name: count, dtype: int64

# %%
# Calculate the correlation matrix
correlation_matrix = gait_dataset.corr()

# Display the correlation matrix
print(correlation_matrix)

# Correlation with the target variable
target_variable = 'target'  # Replace with your actual target column name
correlation_with_target = correlation_matrix[target_variable]

# Display the correlations with the target variable
print(correlation_with_target)

import seaborn as sns
import matplotlib.pyplot as plt

# Plot the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#                      step_time_left  step_time_right  force_asymmetry  \
# step_time_left             1.000000         0.198493        -0.048396
# step_time_right            0.198493         1.000000        -0.039352
# force_asymmetry           -0.048396        -0.039352         1.000000
# stance_time_left          -0.042860        -0.031010         0.147020
# swing_time_left            0.135078         0.124875        -0.233548
# impulse_left              -0.010418         0.001426         0.125027
# stride_length_left        -0.382194        -0.358076         0.156508
# vertical_disp_left         0.591860        -0.100473         0.004206
# foot_velocity_left        -0.801532        -0.266829         0.142697
# peak_force_left           -0.119246        -0.071612         0.211462
# peak_force_right          -0.062881        -0.115025         0.148466
# step_time_diff             0.232596         0.193135         0.108210
# stance_time_right         -0.008521        -0.011719         0.001681
# swing_time_right           0.103214         0.106735        -0.103542
# impulse_right              0.023957         0.023715        -0.024396
# vertical_disp_right       -0.118867         0.640789         0.032017
# foot_velocity_right       -0.286081        -0.801472         0.119485
# stride_length_right       -0.376037        -0.317114         0.175252
# step_width                 0.033820         0.160249         0.117746
# target                     0.365443         0.286010         0.165926
#
#                      stance_time_left  swing_time_left  impulse_left  \
# step_time_left              -0.042860         0.135078     -0.010418
# step_time_right             -0.031010         0.124875      0.001426
# force_asymmetry              0.147020        -0.233548      0.125027
# stance_time_left             1.000000        -0.930312      0.974716
# swing_time_left             -0.930312         1.000000     -0.868675
# impulse_left                 0.974716        -0.868675      1.000000
# stride_length_left           0.097149        -0.318135      0.035860
# vertical_disp_left           0.009519        -0.045711      0.003696
# foot_velocity_left           0.085146        -0.257480      0.031647
# peak_force_left              0.034218        -0.093954      0.092124
# peak_force_right             0.025794        -0.082402      0.086260
# step_time_diff               0.105544         0.012947      0.143613
# stance_time_right           -0.283295         0.235937     -0.289276
# swing_time_right             0.215986        -0.065692      0.259636
# impulse_right               -0.291960         0.282445     -0.284254
# vertical_disp_right          0.023120        -0.062507      0.015898
# foot_velocity_right          0.072654        -0.243575      0.022197
# stride_length_right          0.091799        -0.321646      0.034355
# step_width                  -0.050986         0.063927      0.005653
# target                       0.002776        -0.000770      0.005686
#
#                      stride_length_left  vertical_disp_left  \
# step_time_left                -0.382194            0.591860
# step_time_right               -0.358076           -0.100473
# force_asymmetry                0.156508            0.004206
# stance_time_left               0.097149            0.009519
# swing_time_left               -0.318135           -0.045711
# impulse_left                   0.035860            0.003696
# stride_length_left             1.000000            0.257258
# vertical_disp_left             0.257258            1.000000
# foot_velocity_left             0.671613           -0.499613
# peak_force_left                0.333655           -0.002362
# peak_force_right               0.315814            0.069204
# step_time_diff                -0.400026           -0.107436
# stance_time_right              0.016921            0.007152
# swing_time_right              -0.243163           -0.042783
# impulse_right                 -0.041560            0.000679
# vertical_disp_right            0.256466            0.125548
# foot_velocity_right            0.651424            0.143945
# stride_length_right            0.923330            0.234389
# step_width                     0.032970            0.054948
# target                        -0.537914           -0.265613
#
#                      foot_velocity_left  peak_force_left  peak_force_right  \
# step_time_left                -0.801532        -0.119246         -0.062881
# step_time_right               -0.266829        -0.071612         -0.115025
# force_asymmetry                0.142697         0.211462          0.148466
# stance_time_left               0.085146         0.034218          0.025794
# swing_time_left               -0.257480        -0.093954         -0.082402
# impulse_left                   0.031647         0.092124          0.086260
# stride_length_left             0.671613         0.333655          0.315814
# vertical_disp_left            -0.499613        -0.002362          0.069204
# foot_velocity_left             1.000000         0.293365          0.216238
# peak_force_left                0.293365         1.000000          0.885270
# peak_force_right               0.216238         0.885270          1.000000
# step_time_diff                -0.285058        -0.097262         -0.099370
# stance_time_right              0.016513        -0.107465         -0.098737
# swing_time_right              -0.194377         0.039282          0.035085
# impulse_right                 -0.039443        -0.051650         -0.043359
# vertical_disp_right            0.147452         0.075750         -0.000793
# foot_velocity_right            0.493141         0.234355          0.304683
# stride_length_right            0.650675         0.362841          0.376577
# step_width                    -0.021508         0.440290          0.431049
# target                        -0.339347         0.001387          0.002728
#
#                      step_time_diff  stance_time_right  swing_time_right  \
# step_time_left             0.232596          -0.008521          0.103214
# step_time_right            0.193135          -0.011719          0.106735
# force_asymmetry            0.108210           0.001681         -0.103542
# stance_time_left           0.105544          -0.283295          0.215986
# swing_time_left            0.012947           0.235937         -0.065692
# impulse_left               0.143613          -0.289276          0.259636
# stride_length_left        -0.400026           0.016921         -0.243163
# vertical_disp_left        -0.107436           0.007152         -0.042783
# foot_velocity_left        -0.285058           0.016513         -0.194377
# peak_force_left           -0.097262          -0.107465          0.039282
# peak_force_right          -0.099370          -0.098737          0.035085
# step_time_diff             1.000000           0.165957         -0.048531
# stance_time_right          0.165957           1.000000         -0.940254
# swing_time_right          -0.048531          -0.940254          1.000000
# impulse_right              0.193283           0.974502         -0.878258
# vertical_disp_right       -0.120151          -0.005009         -0.034810
# foot_velocity_right       -0.279127           0.020630         -0.196015
# stride_length_right       -0.399336           0.021013         -0.254783
# step_width                 0.023759          -0.098417          0.114042
# target                     0.310416          -0.007989          0.008633
#
#                      impulse_right  vertical_disp_right  foot_velocity_right  \
# step_time_left            0.023957            -0.118867            -0.286081
# step_time_right           0.023715             0.640789            -0.801472
# force_asymmetry          -0.024396             0.032017             0.119485
# stance_time_left         -0.291960             0.023120             0.072654
# swing_time_left           0.282445            -0.062507            -0.243575
# impulse_left             -0.284254             0.015898             0.022197
# stride_length_left       -0.041560             0.256466             0.651424
# vertical_disp_left        0.000679             0.125548             0.143945
# foot_velocity_left       -0.039443             0.147452             0.493141
# peak_force_left          -0.051650             0.075750             0.234355
# peak_force_right         -0.043359            -0.000793             0.304683
# step_time_diff            0.193283            -0.120151            -0.279127
# stance_time_right         0.974502            -0.005009             0.020630
# swing_time_right         -0.878258            -0.034810            -0.196015
# impulse_right             1.000000            -0.010896            -0.034871
# vertical_disp_right      -0.010896             1.000000            -0.496521
# foot_velocity_right      -0.034871            -0.496521             1.000000
# stride_length_right      -0.037140             0.258463             0.658591
# step_width               -0.051044             0.177780            -0.091209
# target                   -0.008537            -0.274777            -0.328444
#
#                      stride_length_right  step_width    target
# step_time_left                 -0.376037    0.033820  0.365443
# step_time_right                -0.317114    0.160249  0.286010
# force_asymmetry                 0.175252    0.117746  0.165926
# stance_time_left                0.091799   -0.050986  0.002776
# swing_time_left                -0.321646    0.063927 -0.000770
# impulse_left                    0.034355    0.005653  0.005686
# stride_length_left              0.923330    0.032970 -0.537914
# vertical_disp_left              0.234389    0.054948 -0.265613
# foot_velocity_left              0.650675   -0.021508 -0.339347
# peak_force_left                 0.362841    0.440290  0.001387
# peak_force_right                0.376577    0.431049  0.002728
# step_time_diff                 -0.399336    0.023759  0.310416
# stance_time_right               0.021013   -0.098417 -0.007989
# swing_time_right               -0.254783    0.114042  0.008633
# impulse_right                  -0.037140   -0.051044 -0.008537
# vertical_disp_right             0.258463    0.177780 -0.274777
# foot_velocity_right             0.658591   -0.091209 -0.328444
# stride_length_right             1.000000    0.064856 -0.460594
# step_width                      0.064856    1.000000 -0.005669
# target                         -0.460594   -0.005669  1.000000
# step_time_left         0.365443
# step_time_right        0.286010
# force_asymmetry        0.165926
# stance_time_left       0.002776
# swing_time_left       -0.000770
# impulse_left           0.005686
# stride_length_left    -0.537914
# vertical_disp_left    -0.265613
# foot_velocity_left    -0.339347
# peak_force_left        0.001387
# peak_force_right       0.002728
# step_time_diff         0.310416
# stance_time_right     -0.007989
# swing_time_right       0.008633
# impulse_right         -0.008537
# vertical_disp_right   -0.274777
# foot_velocity_right   -0.328444
# stride_length_right   -0.460594
# step_width            -0.005669
# target                 1.000000
# Name: target, dtype: float64

# %%
# Artificial Neural Networks 
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
import scikitplot as skplt  # Make sure scikit-plot is installed
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# Import the dataset
gait_dataset

from sklearn.model_selection import train_test_split

# Separate features and target
X = gait_dataset.drop('target', axis=1)  # Independent variables
y = gait_dataset['target']               # Dependent variable

# Split the data into training, validation, and testing sets directly (no resampling)
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=0, stratify=y_trainval)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_val = sc.transform(X_val)
X_test = sc.transform(X_test)

# Building the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units=9, kernel_initializer='uniform', activation='relu', input_dim=19))

# Adding the second hidden layer
classifier.add(Dense(units=9, kernel_initializer='uniform', activation='relu'))

# Adding the output layer
classifier.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

# Compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Fitting the ANN to the training set with separate validation set
history = classifier.fit(X_train, y_train, validation_data=(X_val, y_val), batch_size=10, epochs=100)

# Predicting the Test set results
y_pred_proba = classifier.predict(X_test)  # Get probabilities for ROC and AUC
y_pred = (y_pred_proba > 0.5)  # Convert probabilities to class labels

# Making the Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Print Classification Report and Confusion Matrix for test set
print("\nANN Classifier:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(cm)

# Calculate per-class accuracies
per_class_accuracies = cm.diagonal() / cm.sum(axis=1)
for cls, acc in enumerate(per_class_accuracies):
    print(f"Accuracy for class {cls}: {acc:.4f}")

# Visualize the Confusion Matrix
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=False, title='Confusion Matrix for ANN Classifier')
plt.show()

# Visualize the ROC Curve
# Compute ROC curve and ROC area for the positive class
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Calculate AUC Score
auc_value = roc_auc_score(y_test, y_pred_proba)
print(f"AUC: {auc_value:.2f}")
# Out:
# C:\Users\opeye\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7701 - loss: 0.4754 - val_accuracy: 0.9887 - val_loss: 0.0467
# Epoch 2/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0329 - val_accuracy: 0.9940 - val_loss: 0.0237
# Epoch 3/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9951 - loss: 0.0220 - val_accuracy: 0.9960 - val_loss: 0.0197
# Epoch 4/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9968 - loss: 0.0124 - val_accuracy: 0.9944 - val_loss: 0.0251
# Epoch 5/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9971 - loss: 0.0102 - val_accuracy: 0.9960 - val_loss: 0.0152
# Epoch 6/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9983 - loss: 0.0071 - val_accuracy: 0.9964 - val_loss: 0.0150
# Epoch 7/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9982 - loss: 0.0051 - val_accuracy: 0.9968 - val_loss: 0.0143
# Epoch 8/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9979 - loss: 0.0060 - val_accuracy: 0.9980 - val_loss: 0.0116
# Epoch 9/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9980 - val_loss: 0.0117
# Epoch 10/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.9976 - val_loss: 0.0106
# Epoch 11/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9993 - loss: 0.0039 - val_accuracy: 0.9980 - val_loss: 0.0084
# Epoch 12/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 0.9972 - val_loss: 0.0142
# Epoch 13/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9998 - loss: 0.0017 - val_accuracy: 0.9980 - val_loss: 0.0069
# Epoch 14/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9980 - val_loss: 0.0106
# Epoch 15/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9994 - loss: 0.0016 - val_accuracy: 0.9984 - val_loss: 0.0088
# Epoch 16/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9999 - loss: 9.0809e-04 - val_accuracy: 0.9980 - val_loss: 0.0078
# Epoch 17/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.7928e-04 - val_accuracy: 0.9980 - val_loss: 0.0088
# Epoch 18/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 4.6425e-04 - val_accuracy: 0.9980 - val_loss: 0.0103
# Epoch 19/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 6.0979e-04 - val_accuracy: 0.9924 - val_loss: 0.0173
# Epoch 20/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9980 - val_loss: 0.0079
# Epoch 21/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 2.1967e-04 - val_accuracy: 0.9976 - val_loss: 0.0103
# Epoch 22/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 3.1319e-04 - val_accuracy: 0.9984 - val_loss: 0.0069
# Epoch 23/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.9041e-04 - val_accuracy: 0.9984 - val_loss: 0.0081
# Epoch 24/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 2.1467e-04 - val_accuracy: 0.9980 - val_loss: 0.0072
# Epoch 25/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.2624e-04 - val_accuracy: 0.9984 - val_loss: 0.0068
# Epoch 26/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 2.0030e-04 - val_accuracy: 0.9984 - val_loss: 0.0059
# Epoch 27/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.1676e-04 - val_accuracy: 0.9984 - val_loss: 0.0071
# Epoch 28/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.7034e-05 - val_accuracy: 0.9984 - val_loss: 0.0070
# Epoch 29/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 3.2568e-05 - val_accuracy: 0.9988 - val_loss: 0.0055
# Epoch 30/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 0.9984 - val_loss: 0.0096
# Epoch 31/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.4683e-05 - val_accuracy: 0.9984 - val_loss: 0.0083
# Epoch 32/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.8109e-05 - val_accuracy: 0.9984 - val_loss: 0.0079
# Epoch 33/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 1.0000 - loss: 1.3926e-05 - val_accuracy: 0.9984 - val_loss: 0.0066
# Epoch 34/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.7154e-05 - val_accuracy: 0.9984 - val_loss: 0.0070
# Epoch 35/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.2523e-05 - val_accuracy: 0.9992 - val_loss: 0.0057
# Epoch 36/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.3047e-05 - val_accuracy: 0.9988 - val_loss: 0.0066
# Epoch 37/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.1189e-05 - val_accuracy: 0.9984 - val_loss: 0.0059
# Epoch 38/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 5.8194e-05 - val_accuracy: 0.9984 - val_loss: 0.0084
# Epoch 39/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.2313e-04 - val_accuracy: 0.9988 - val_loss: 0.0057
# Epoch 40/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9990 - loss: 0.0037 - val_accuracy: 0.9984 - val_loss: 0.0170
# Epoch 41/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 8.7420e-05 - val_accuracy: 0.9984 - val_loss: 0.0127
# Epoch 42/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 3.2145e-05 - val_accuracy: 0.9984 - val_loss: 0.0127
# Epoch 43/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.5664e-05 - val_accuracy: 0.9984 - val_loss: 0.0122
# Epoch 44/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.6485e-05 - val_accuracy: 0.9984 - val_loss: 0.0117
# Epoch 45/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 9.7337e-06 - val_accuracy: 0.9984 - val_loss: 0.0112
# Epoch 46/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.7031e-06 - val_accuracy: 0.9984 - val_loss: 0.0110
# Epoch 47/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 1.2165e-05 - val_accuracy: 0.9984 - val_loss: 0.0104
# Epoch 48/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.1935e-05 - val_accuracy: 0.9984 - val_loss: 0.0107
# Epoch 49/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 6.7405e-06 - val_accuracy: 0.9984 - val_loss: 0.0098
# Epoch 50/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 8.4915e-06 - val_accuracy: 0.9984 - val_loss: 0.0097
# Epoch 51/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 6.4645e-06 - val_accuracy: 0.9984 - val_loss: 0.0111
# Epoch 52/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9999 - loss: 2.9968e-04 - val_accuracy: 0.9984 - val_loss: 0.0133
# Epoch 53/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9996 - loss: 7.5565e-04 - val_accuracy: 0.9968 - val_loss: 0.0092
# Epoch 54/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9996 - loss: 5.8929e-04 - val_accuracy: 0.9980 - val_loss: 0.0113
# Epoch 55/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 2.1461e-04 - val_accuracy: 0.9984 - val_loss: 0.0155
# Epoch 56/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9984 - val_loss: 0.0118
# Epoch 57/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 7.0023e-06 - val_accuracy: 0.9984 - val_loss: 0.0115
# Epoch 58/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 4.9109e-06 - val_accuracy: 0.9984 - val_loss: 0.0113
# Epoch 59/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.9051e-06 - val_accuracy: 0.9984 - val_loss: 0.0111
# Epoch 60/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 5.1007e-06 - val_accuracy: 0.9984 - val_loss: 0.0108
# Epoch 61/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.4406e-06 - val_accuracy: 0.9984 - val_loss: 0.0104
# Epoch 62/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 2.7821e-06 - val_accuracy: 0.9984 - val_loss: 0.0094
# Epoch 63/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.7246e-06 - val_accuracy: 0.9992 - val_loss: 0.0087
# Epoch 64/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.4173e-06 - val_accuracy: 0.9992 - val_loss: 0.0088
# Epoch 65/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.4745e-06 - val_accuracy: 0.9992 - val_loss: 0.0086
# Epoch 66/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 9.4234e-07 - val_accuracy: 0.9992 - val_loss: 0.0079
# Epoch 67/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.3342e-06 - val_accuracy: 0.9992 - val_loss: 0.0079
# Epoch 68/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.1862e-06 - val_accuracy: 0.9992 - val_loss: 0.0085
# Epoch 69/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 9.0881e-07 - val_accuracy: 0.9992 - val_loss: 0.0087
# Epoch 70/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9999 - loss: 5.5374e-04 - val_accuracy: 0.9992 - val_loss: 0.0075
# Epoch 71/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 1.0000 - loss: 5.4993e-05 - val_accuracy: 0.9992 - val_loss: 0.0079
# Epoch 72/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 8.5946e-06 - val_accuracy: 0.9992 - val_loss: 0.0073
# Epoch 73/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.6281e-06 - val_accuracy: 0.9992 - val_loss: 0.0073
# Epoch 74/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 5.1324e-06 - val_accuracy: 0.9992 - val_loss: 0.0072
# Epoch 75/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.6395e-06 - val_accuracy: 0.9992 - val_loss: 0.0072
# Epoch 76/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.3300e-06 - val_accuracy: 0.9992 - val_loss: 0.0070
# Epoch 77/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.2960e-06 - val_accuracy: 0.9992 - val_loss: 0.0071
# Epoch 78/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 8.8211e-07 - val_accuracy: 0.9992 - val_loss: 0.0069
# Epoch 79/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 7.0296e-07 - val_accuracy: 0.9992 - val_loss: 0.0071
# Epoch 80/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 7.9043e-07 - val_accuracy: 0.9992 - val_loss: 0.0068
# Epoch 81/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 6.6465e-07 - val_accuracy: 0.9992 - val_loss: 0.0072
# Epoch 82/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.4575e-07 - val_accuracy: 0.9984 - val_loss: 0.0078
# Epoch 83/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 5.7186e-07 - val_accuracy: 0.9988 - val_loss: 0.0078
# Epoch 84/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 4.0953e-07 - val_accuracy: 0.9984 - val_loss: 0.0084
# Epoch 85/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 3.1935e-07 - val_accuracy: 0.9984 - val_loss: 0.0082
# Epoch 86/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 2.8189e-07 - val_accuracy: 0.9992 - val_loss: 0.0067
# Epoch 87/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.2406e-07 - val_accuracy: 0.9992 - val_loss: 0.0068
# Epoch 88/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.0222e-07 - val_accuracy: 0.9984 - val_loss: 0.0086
# Epoch 89/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9999 - loss: 3.5005e-04 - val_accuracy: 0.9988 - val_loss: 0.0049
# Epoch 90/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.4933e-04 - val_accuracy: 0.9984 - val_loss: 0.0095
# Epoch 91/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 4.7265e-05 - val_accuracy: 0.9988 - val_loss: 0.0064
# Epoch 92/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.7939e-06 - val_accuracy: 0.9988 - val_loss: 0.0066
# Epoch 93/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.5235e-06 - val_accuracy: 0.9988 - val_loss: 0.0068
# Epoch 94/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 1.4226e-06 - val_accuracy: 0.9988 - val_loss: 0.0069
# Epoch 95/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 7.4439e-07 - val_accuracy: 0.9988 - val_loss: 0.0071
# Epoch 96/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.7119e-07 - val_accuracy: 0.9988 - val_loss: 0.0072
# Epoch 97/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 6.7931e-07 - val_accuracy: 0.9988 - val_loss: 0.0073
# Epoch 98/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 3.4934e-07 - val_accuracy: 0.9992 - val_loss: 0.0074
# Epoch 99/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 4.9797e-07 - val_accuracy: 0.9992 - val_loss: 0.0075
# Epoch 100/100
# 746/746 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 2.7839e-07 - val_accuracy: 0.9992 - val_loss: 0.0075
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#
# ANN Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1492
#            1       1.00      1.00      1.00       994
#
#     accuracy                           1.00      2486
#    macro avg       1.00      1.00      1.00      2486
# weighted avg       1.00      1.00      1.00      2486
#
# Confusion Matrix:
# [[1492    0]
#  [   1  993]]
# Accuracy for class 0: 1.0000
# Accuracy for class 1: 0.9990
# AUC: 1.00

# %%
# SVC Classifier
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.over_sampling import RandomOverSampler

# Import the dataset
gait_dataset

# Separate features and target
X = gait_dataset.drop('target', axis=1)  # Independent variables
y = gait_dataset['target']               # Dependent variable

# Split the data into training, validation, and testing sets directly (no resampling)
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=0, stratify=y_trainval)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_val = sc.transform(X_val)
X_test = sc.transform(X_test)

# If you must stick with LinearSVC, you can use the decision_function and apply a transformation (e.g., sigmoid) to approximate probabilities
# Instantiate the LinearSVC model
from sklearn.svm import LinearSVC
from sklearn.calibration import CalibratedClassifierCV

# Wrap LinearSVC in a calibration model
SVCclassifier = LinearSVC(C=5, random_state=0, max_iter=10000)
SVCmodel = CalibratedClassifierCV(SVCclassifier, method='sigmoid')
SVCmodel.fit(X_train, y_train)


# Perform Cross Validation on the training set
k = 5  # Reduced from 10 for faster computation
scores = cross_val_score(SVCmodel, X_trainval, y_trainval, cv=k)

print("Cross Validation Scores:", scores)
print("Average CV Score:", scores.mean())
# Out:
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# Cross Validation Scores: [0.88838612 0.89291101 0.89441931 0.88838612 0.888833  ]
# Average CV Score: 0.8905871124180983
# C:\Users\opeye\anaconda3\Lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
print("Shape of y_pred_proba:", y_pred_proba.shape)
print("Unique classes in y_test:", np.unique(y_test))
# Out:
# Shape of y_pred_proba: (2486, 2)
# Unique classes in y_test: [0 1]

# %%
import scikitplot as skplt  # Make sure scikit-plot is installed
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import scikitplot as skplt
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score

# Make predictions on the validation set using the best model
y_pred_val = SVCmodel.predict(X_val)

# Evaluate the model on validation set
accuracy_val = accuracy_score(y_val, y_pred_val)
print("Validation Accuracy :", accuracy_val)

# Make predictions on the test set
y_pred_test = SVCmodel.predict(X_test)

# Evaluate the model on test set SVCclassifier
accuracy_test = accuracy_score(y_test, y_pred_test)
print("Test Accuracy:", accuracy_test)

# Print Classification Report and Confusion Matrix for test set
print("\nSVC Classifier:")
print(classification_report(y_test, y_pred_test))
cm = confusion_matrix(y_test, y_pred_test)
print("Confusion Matrix:")
print(cm)
per_class_accuracies = cm.diagonal() / cm.sum(axis=1)
for cls, acc in enumerate(per_class_accuracies):
    print(f"Accuracy for class {cls}: {acc:.4f}")

# Visualize the Confusion Matrix
skplt.metrics.plot_confusion_matrix(y_test, y_pred_test, normalize=False, title='Confusion Matrix for SVC')
plt.show()

# Visualize the ROC Curve
# Now you can use predict_proba
y_pred_proba = SVCmodel.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_pred_proba, title='ROC Plot for SVC')
plt.show()

# Calculate AUC Score for the test set
from sklearn.metrics import roc_auc_score

# Extract only probabilities for class 1 (positive class)
auc_value = roc_auc_score(y_test, y_pred_proba[:, 1])
print(f"AUC SVC: {auc_value:.2f}")
# Out:
# Validation Accuracy : 0.9935639581657281
# Test Accuracy: 0.9931617055510861
#
# SVC Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1492
#            1       0.99      0.99      0.99       994
#
#     accuracy                           0.99      2486
#    macro avg       0.99      0.99      0.99      2486
# weighted avg       0.99      0.99      0.99      2486
#
# Confusion Matrix:
# [[1480   12]
#  [   5  989]]
# Accuracy for class 0: 0.9920
# Accuracy for class 1: 0.9950
# AUC SVC: 1.00

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
import scikitplot as skplt
import matplotlib.pyplot as plt

# Import the dataset
gait_dataset

# Separate features and target
X = gait_dataset.drop('target', axis=1)  # Independent variables
y = gait_dataset['target']               # Dependent variable

# Train-validation-test split (no oversampling)
X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.25, random_state=0, stratify=y_trainval)

# Train Random Forest Classifier using default parameters
rf_classifier = RandomForestClassifier(random_state=0)
rf_classifier.fit(X_trainval, y_trainval)

# Validation evaluation
y_pred_val = rf_classifier.predict(X_val)
accuracy_val = accuracy_score(y_val, y_pred_val)
print("Validation Accuracy:", accuracy_val)

# Test predictions and evaluation
y_predrf = rf_classifier.predict(X_test)
accuracy_test = accuracy_score(y_test, y_predrf)
print("Test Accuracy:", accuracy_test)

# Classification metrics
print("\nRandom Forest Classifier:")
print(classification_report(y_test, y_predrf))
cm = confusion_matrix(y_test, y_predrf)
print("Confusion Matrix:")
print(cm)

# Per-class accuracy
per_class_accuracies = cm.diagonal() / cm.sum(axis=1)
for cls, acc in enumerate(per_class_accuracies):
    print(f"Accuracy for class {cls}: {acc:.4f}")

# Confusion matrix plot
skplt.metrics.plot_confusion_matrix(y_test, y_predrf, normalize=False, title='Confusion Matrix for RF Classifier')
plt.show()

# ROC curve
y_pred_proba = rf_classifier.predict_proba(X_test)
skplt.metrics.plot_roc(y_test, y_pred_proba, title='ROC Plot for RF Classifier')
plt.show()

# AUC score
if y_pred_proba.shape[1] == 2:
    auc_value = roc_auc_score(y_test, y_pred_proba[:, 1])
    print(f"AUC: {auc_value:.2f}")
else:
    auc_value = roc_auc_score(y_test, y_pred_proba, multi_class='ovr')
    print(f"Multiclass AUC: {auc_value:.2f}")
# Out:
# Validation Accuracy: 1.0
# Test Accuracy: 0.999597747385358
#
# Random Forest Classifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1492
#            1       1.00      1.00      1.00       994
#
#     accuracy                           1.00      2486
#    macro avg       1.00      1.00      1.00      2486
# weighted avg       1.00      1.00      1.00      2486
#
# Confusion Matrix:
# [[1492    0]
#  [   1  993]]
# Accuracy for class 0: 1.0000
# Accuracy for class 1: 0.9990
# AUC: 1.00
